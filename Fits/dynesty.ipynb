# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as numpy
import matplotlib.pyplot as plt
import os
from multiprocessing import Pool
import dynesty
from dynesty import plotting as dyplot
from chi2_functions import *

# %%
def prior_transform(u):
  u_ampT8X8, u_ampC8X8, u_ampPuc8X8, u_ampA8X8, u_ampPAuc8X8, u_ampPtc8X8, u_ampPAtc8X8,\
  u_delC8X8, u_delPuc8X8, u_delA8X8, u_delPAuc8X8, u_delPtc8X8, u_delPAtc8X8,\
  u_ampT8X1, u_ampC8X1, u_ampPuc8X1, u_ampPtc8X1,\
  u_delT8X1, u_delC8X1, u_delPuc8X1, u_delPtc8X1,\
  u_ampC1X1, u_ampPtc1X1,\
  u_delC1X1, u_delPtc1X1 = u

  ampT8X8 = 10 + 10*u_ampT8X8
  ampC8X8 = 10 + 10*u_ampC8X8
  ampPuc8X8 = 10 + 10*u_ampPuc8X8
  ampA8X8 = 10 + 10*u_ampA8X8
  ampPAuc8X8 = 10 + 10*u_ampPAuc8X8
  ampPtc8X8 = 10 + 10*u_ampPtc8X8
  ampPAtc8X8 = 10 + 10*u_ampPAtc8X8

  delC8X8 = 2*np.pi*u_delC8X8
  delPuc8X8 = 2*np.pi*u_delPuc8X8
  delA8X8 = 2*np.pi*u_delA8X8
  delPAuc8X8 = 2*np.pi*u_delPAuc8X8
  delPtc8X8 = 2*np.pi*u_delPtc8X8
  delPAtc8X8 = 2*np.pi*u_delPAtc8X8

  ampT8X1 = 10 + 10*u_ampT8X1
  ampC8X1 = 10 + 10*u_ampC8X1
  ampPuc8X1 = 10 + 10*u_ampPuc8X1
  ampPtc8X1 = 10 + 10*u_ampPtc8X1

  delT8X1 = 2*np.pi*u_delT8X1
  delC8X1 = 2*np.pi*u_delC8X1
  delPuc8X1 = 2*np.pi*u_delPuc8X1
  delPtc8X1 = 2*np.pi*u_delPtc8X1

  ampC1X1 = 10 + 10*u_ampC1X1
  ampPtc1X1 = 10 + 10*u_ampPtc1X1
  
  delC1X1 = 2*np.pi*u_delC1X1
  delPtc1X1 = 2*np.pi*u_delPtc1X1

  return (ampT8X8, ampC8X8, ampPuc8X8, ampA8X8, ampPAuc8X8, ampPtc8X8, ampPAtc8X8,\
          delC8X8, delPuc8X8, delA8X8, delPAuc8X8, delPtc8X8, delPAtc8X8,\
          ampT8X1, ampC8X1, ampPuc8X1, ampPtc8X1,\
          delT8X1, delC8X1, delPuc8X1, delPtc8X1,\
          ampC1X1, ampPtc1X1,\
          delC1X1, delPtc1X1)

# %%
ndim  = 25
nlive = 2000

# Run and Save Dynesty
# nworkers = os.cpu_count()
# pool     = Pool(nworkers)
sampler  = dynesty.DynamicNestedSampler(chi2,
                                        prior_transform, 
                                        sample='rslice',
                                        ndim=ndim, 
                                        nlive=nlive,
                                        bound='multi')
                                        #pool=pool, 
                                        #queue_size=nworkers)
sampler.run_nested()
# pool.close()
# pool.join()
results = sampler.results
# Out:
# iter: 60316 | batch: 0 | bound: 75 | nc: 153 | ncall: 8410022 | eff(%):  0.717 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-  0.112 | dlogz:    inf >  0.010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 15
#       7 sampler  = dynesty.DynamicNestedSampler(chi2,
#       8                                         prior_transform,
#       9                                         sample='rslice',
#      10                                         ndim=ndim,
#      11                                         nlive=nlive,
#      12                                         bound='multi')
#      13                                         #pool=pool,
#      14                                         #queue_size=nworkers)
# ---> 15 sampler.run_nested()
#      16 # pool.close()
#      17 # pool.join()
#      18 results = sampler.results
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\dynamicsampler.py:2055, in DynamicSampler.run_nested(self, nlive_init, maxiter_init, maxcall_init, dlogz_init, logl_max_init, n_effective_init, nlive_batch, wt_function, wt_kwargs, maxiter_batch, maxcall_batch, maxiter, maxcall, maxbatch, n_effective, stop_function, stop_kwargs, use_stop, save_bounds, print_progress, print_func, live_points, resume, checkpoint_file, checkpoint_every)
#    2053 try:
#    2054     if not self.base:
# -> 2055         for results in self.sample_initial(
#    2056                 nlive=nlive_init,
#    2057                 dlogz=dlogz_init,
#    2058                 maxcall=maxcall_init,
#    2059                 maxiter=maxiter_init,
#    2060                 logl_max=logl_max_init,
#    2061                 live_points=live_points,
#    2062                 n_effective=n_effective_init,
#    2063                 resume=resume,
#    2064                 save_samples=True):
#    2065             if resume:
#    2066                 resume = False
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\dynamicsampler.py:1336, in DynamicSampler.sample_initial(self, nlive, update_interval, first_update, maxiter, maxcall, logl_max, dlogz, n_effective, live_points, save_samples, resume)
#    1334     self.internal_state = DynamicSamplerStatesEnum.LIVEPOINTSINIT
#    1335     # Run the sampler internally as a generator.
# -> 1336 for it, results in enumerate(
#    1337         self.sampler.sample(maxiter=maxiter,
#    1338                             save_samples=save_samples,
#    1339                             maxcall=maxcall,
#    1340                             logl_max=logl_max,
#    1341                             dlogz=dlogz,
#    1342                             resume=resume)):
#    1343     # Grab results.
#    1344
#    1345     # Save our base run (which we will use later).
#    1346     add_info = dict(id=results.worst,
#    1347                     u=results.ustar,
#    1348                     v=results.vstar,
#    (...)
#    1360                     bounditer=results.bounditer,
#    1361                     scale=self.sampler.scale)
#    1363     self.base_run.append(add_info)
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\sampler.py:848, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples, resume)
#     843     old_blob = None
#     845 # Sample a new live point from within the likelihood constraint
#     846 # `logl > loglstar` using the bounding distribution and sampling
#     847 # method from our sampler.
# --> 848 u, v, logl, nc = self._new_point(loglstar_new)
#     849 ncall += nc
#     850 self.ncall += nc
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\sampler.py:421, in Sampler._new_point(self, loglstar)
#     418 ncall_accum = 0
#     419 while True:
#     420     # Get the next point from the queue
# --> 421     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     422     ncall += nc
#     423     ncall_accum += nc
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\sampler.py:404, in Sampler._get_point_value(self, loglstar)
#     402 # If the queue is empty, refill it.
#     403 if self.nqueue <= 0:
# --> 404     self._fill_queue(loglstar)
#     406 # Grab the earliest entry.
#     407 u, v, logl, nc, blob = self.queue.pop(0)
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\sampler.py:397, in Sampler._fill_queue(self, loglstar)
#     387 for i in range(self.queue_size):
#     388     args.append(
#     389         SamplerArgument(u=point_queue[i],
#     390                         loglstar=loglstar,
#    (...)
#     395                         rseed=seeds[i],
#     396                         kwargs=self.kwargs))
# --> 397 self.queue = list(mapper(evolve_point, args))
#
# File c:\Users\alexa\miniconda3\envs\su3flavour\lib\site-packages\dynesty\sampling.py:671, in sample_rslice(args)
#     668 drhat /= linalg.norm(drhat)
#     670 # Transform and scale based on past tuning.
# --> 671 direction = np.dot(axes, drhat) * scale
#     673 (u_prop, v_prop, logl_prop, nc1, nexpand1, ncontract1,
#     674  expansion_warning) = generic_slice_step(u, direction, nonperiodic,
#     675                                          loglstar, loglikelihood,
#     676                                          prior_transform, doubling,
#     677                                          rstate)
#     678 u = u_prop
#
# KeyboardInterrupt:
